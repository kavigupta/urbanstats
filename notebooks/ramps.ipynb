# %%
import os

os.chdir("..")

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
from urbanstats.mapper.ramp import get_all_ramps, plot_ramp

# %%
all_ramps = get_all_ramps()

# %%
plt.figure(figsize=(5, 15), facecolor="white")
ys = list(all_ramps)[::-1]
for i, k in enumerate(ys):
    plot_ramp(i, all_ramps[k]["ramp"])
plt.yticks(np.arange(len(ys)), ys)
plt.show()
